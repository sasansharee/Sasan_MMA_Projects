# %% [markdown]
# <a href="https://colab.research.google.com/github/sasansharee/Sasan_MMA_Projects/blob/main/Auto_Scout_project_SVM_Classification_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_org = pd.read_csv('df_33_cleaned_filled_outlier_dummies.csv')

# %%
df = df_org.copy()

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['fuel_Diesel'], axis = 1)
y = df['fuel_Diesel']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %% [markdown]
# ### **Modelling and Model Performance**

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report

# %%
def eval_metric (model, X_train, y_train, X_test, y_test):
  y_train_pred = model.predict(X_train)
  y_pred = model.predict(X_test)

  print('Test_Set:')
  print(confusion_matrix(y_test, y_pred))
  print(classification_report(y_test, y_pred))

  print()

  print('Train_Set:')
  print(confusion_matrix(y_train, y_train_pred))
  print(classification_report(y_train, y_train_pred))

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((11939, 138), (3980, 138), (11939,), (3980,))

# %%
sum(y_train), sum(y_test), sum(y_train) / len(y_train), sum(y_test) / len(y_test)
# Out:
# (5474, 1825, 0.4584973615880727, 0.4585427135678392)

# %% [markdown]
# **Without Scalling**

# %%
svc = SVC(random_state = 42)
svc.fit(X_train, y_train)
# Out:
# SVC(random_state=42)

# %%
eval_metric(svc, X_train, y_train, X_test, y_test)
# Out:
# Test_Set:
# [[1670  485]
#  [ 574 1251]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.76      2155
#            1       0.72      0.69      0.70      1825
#
#     accuracy                           0.73      3980
#    macro avg       0.73      0.73      0.73      3980
# weighted avg       0.73      0.73      0.73      3980
#
#
# Train_Set:
# [[5042 1423]
#  [1727 3747]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76      6465
#            1       0.72      0.68      0.70      5474
#
#     accuracy                           0.74     11939
#    macro avg       0.73      0.73      0.73     11939
# weighted avg       0.74      0.74      0.74     11939

# %%
from sklearn.model_selection import cross_validate

# %%
scores_svc = cross_validate(svc, X_train, y_train, scoring = ['precision', 'recall', 'f1'], cv = 10)
scores_svc
# Out:
# {'fit_time': array([34.12228632, 18.96719432, 11.92004681, 11.90899467, 10.94027042,
#         13.95889878, 14.65532112, 12.9594326 , 16.65679836, 15.8993268 ]),
#  'score_time': array([3.39295292, 0.98198748, 0.95843363, 0.98391175, 1.15312719,
#         1.1050899 , 1.03825903, 1.23225236, 1.53352189, 1.28563714]),
#  'test_precision': array([0.72900763, 0.72064777, 0.72275335, 0.73306773, 0.71968191,
#         0.73120301, 0.74451098, 0.6969697 , 0.69074074, 0.72277228]),
#  'test_recall': array([0.69708029, 0.64963504, 0.68978102, 0.67153285, 0.66179159,
#         0.71115174, 0.68190128, 0.67276051, 0.68190128, 0.66727605]),
#  'test_f1': array([0.71268657, 0.68330134, 0.70588235, 0.70095238, 0.68952381,
#         0.721038  , 0.71183206, 0.68465116, 0.68629255, 0.69391635])}

# %%
scores_svc_df = pd.DataFrame(scores_svc, index = range(1, 11))
scores_svc_df.iloc[:, 2:].mean()
# Out:
# test_precision    0.721136
# test_recall       0.678481
# test_f1           0.699008
# dtype: float64

# %% [markdown]
# **With Scaling**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps = [('scaler', StandardScaler()),
                         ('svc', SVC())])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('svc', SVC())])

# %%
eval_metric(pipe, X_train, y_train, X_test, y_test)
# Out:
# Test_Set:
# [[2118   37]
#  [  22 1803]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      2155
#            1       0.98      0.99      0.98      1825
#
#     accuracy                           0.99      3980
#    macro avg       0.98      0.99      0.99      3980
# weighted avg       0.99      0.99      0.99      3980
#
#
# Train_Set:
# [[6426   39]
#  [  50 5424]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6465
#            1       0.99      0.99      0.99      5474
#
#     accuracy                           0.99     11939
#    macro avg       0.99      0.99      0.99     11939
# weighted avg       0.99      0.99      0.99     11939

# %%
scores_svc_pipe = cross_validate(pipe, X_train, y_train, scoring = ['precision', 'recall', 'f1'], cv = 10)
scores_svc_pipe
# Out:
# {'fit_time': array([5.38705206, 5.51683736, 5.53672957, 5.62089252, 5.71801114,
#         5.80050278, 5.65854859, 5.66220903, 5.47935939, 5.61988711]),
#  'score_time': array([0.38601112, 0.36388302, 0.40809131, 0.4080143 , 0.38178134,
#         0.38871837, 0.41097283, 0.37136316, 0.43110347, 0.24242973]),
#  'test_precision': array([0.98188406, 0.98348624, 0.98025135, 0.97644928, 0.97449909,
#         0.9801085 , 0.97996357, 0.98710866, 0.96953405, 0.97632058]),
#  'test_recall': array([0.98905109, 0.97810219, 0.99635036, 0.98357664, 0.97806216,
#         0.99085923, 0.98354662, 0.97989031, 0.98903108, 0.97989031]),
#  'test_f1': array([0.98545455, 0.98078683, 0.98823529, 0.98      , 0.97627737,
#         0.98545455, 0.98175182, 0.98348624, 0.97918552, 0.97810219])}

# %%
scores_svc_pipe_df = pd.DataFrame(scores_svc_pipe, index = range(1, 11))
scores_svc_pipe_df.iloc[:, 2:].mean()
# Out:
# test_precision    0.978961
# test_recall       0.984836
# test_f1           0.981873
# dtype: float64

# %% [markdown]
# **With Best Parameters (GridsearchCV)**

# %%
from sklearn.model_selection import GridSearchCV

# %%
pipe2 = Pipeline(steps = [('scaler', StandardScaler()),
                          ('SVC', SVC(class_weight = 'balanced', probability = True, random_state = 42))])

# %%
param_grid = {'SVC__C': [0.001, 0.05, 0.01],
              'SVC__gamma': ['scale', 'auto', 0.2, 0.3],
              'SVC__kernel': ['rbf', 'linear']}

# %%
svm_grid = GridSearchCV(pipe2, param_grid, scoring = 'recall', cv = 10)
svm_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('SVC',
#                                         SVC(class_weight='balanced',
#                                             probability=True,
#                                             random_state=42))]),
#              param_grid={'SVC__C': [0.001, 0.05, 0.01],
#                          'SVC__gamma': ['scale', 'auto', 0.2, 0.3],
#                          'SVC__kernel': ['rbf', 'linear']},
#              scoring='recall')

# %%
svm_grid.best_params_
# Out:
# {'SVC__C': 0.05, 'SVC__gamma': 'scale', 'SVC__kernel': 'linear'}

# %%
svm_grid.best_index_
# Out:
# np.int64(9)

# %%
svm_grid.best_score_
# Out:
# np.float64(0.9819136230801051)

# %%
svm_grid_df = pd.DataFrame(svm_grid.cv_results_)

# %%
svm_grid_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      128.530412     14.001681         2.261751        0.211929
# 1       34.314155      0.532184         0.143551        0.011163
# 2      140.451139      7.341059         2.347939        0.094860
# 3       31.292923      0.815972         0.148365        0.011600
# 4      144.761409      8.094940         2.364609        0.071534
# 5       32.906212      2.560360         0.140664        0.021028
# 6      160.975164      5.401573         2.384593        0.100455
# 7       35.113424      1.168950         0.138553        0.009088
# 8       82.795543      5.187467         0.952798        0.095275
# 9       10.370149      0.282218         0.038577        0.002919
# 10      86.290676      4.024018         1.084827        0.087412
# 11      11.447177      0.645099         0.049610        0.005791
# 12     145.848623     40.944596         2.319893        0.688277
# 13       4.798779      0.212187         0.024066        0.001610
# 14      74.963943      2.466003         1.551440        0.110114
# 15       5.407379      0.320264         0.029765        0.001183
# 16      58.097122      4.116005         1.201831        0.137860
# 17       6.134077      0.328704         0.041575        0.003370
# 18      52.474948      1.464440         1.146426        0.117690
# 19       6.002402      0.298804         0.043494        0.003461
# 20      64.055229      1.178420         1.431764        0.154022
# 21       6.075035      0.332136         0.042432        0.002232
# 22      64.837971      1.108213         1.423571        0.126596
# 23       6.122932      0.321067         0.043616        0.003400
#
#     param_SVC__C param_SVC__gamma param_SVC__kernel  \
# 0          0.001            scale               rbf
# 1          0.001            scale            linear
# 2          0.001             auto               rbf
# 3          0.001             auto            linear
# 4          0.001              0.2               rbf
# 5          0.001              0.2            linear
# 6          0.001              0.3               rbf
# 7          0.001              0.3            linear
# 8          0.050            scale               rbf
# 9          0.050            scale            linear
# 10         0.050             auto               rbf
# 11         0.050             auto            linear
# 12         0.050              0.2               rbf
# 13         0.050              0.2            linear
# 14         0.050              0.3               rbf
# 15         0.050              0.3            linear
# 16         0.010            scale               rbf
# 17         0.010            scale            linear
# 18         0.010             auto               rbf
# 19         0.010             auto            linear
# 20         0.010              0.2               rbf
# 21         0.010              0.2            linear
# 22         0.010              0.3               rbf
# 23         0.010              0.3            linear
#
#                                                params  split0_test_score  \
# 0   {'SVC__C': 0.001, 'SVC__gamma': 'scale', 'SVC_...           1.000000
# 1   {'SVC__C': 0.001, 'SVC__gamma': 'scale', 'SVC_...           0.976277
# 2   {'SVC__C': 0.001, 'SVC__gamma': 'auto', 'SVC__...           1.000000
# 3   {'SVC__C': 0.001, 'SVC__gamma': 'auto', 'SVC__...           0.976277
# 4   {'SVC__C': 0.001, 'SVC__gamma': 0.2, 'SVC__ker...           1.000000
# 5   {'SVC__C': 0.001, 'SVC__gamma': 0.2, 'SVC__ker...           0.976277
# 6   {'SVC__C': 0.001, 'SVC__gamma': 0.3, 'SVC__ker...           1.000000
# 7   {'SVC__C': 0.001, 'SVC__gamma': 0.3, 'SVC__ker...           0.976277
# 8   {'SVC__C': 0.05, 'SVC__gamma': 'scale', 'SVC__...           0.963504
# 9   {'SVC__C': 0.05, 'SVC__gamma': 'scale', 'SVC__...           0.981752
# 10  {'SVC__C': 0.05, 'SVC__gamma': 'auto', 'SVC__k...           0.963504
# 11  {'SVC__C': 0.05, 'SVC__gamma': 'auto', 'SVC__k...           0.981752
# 12  {'SVC__C': 0.05, 'SVC__gamma': 0.2, 'SVC__kern...           0.118613
# 13  {'SVC__C': 0.05, 'SVC__gamma': 0.2, 'SVC__kern...           0.981752
# 14  {'SVC__C': 0.05, 'SVC__gamma': 0.3, 'SVC__kern...           0.082117
# 15  {'SVC__C': 0.05, 'SVC__gamma': 0.3, 'SVC__kern...           0.981752
# 16  {'SVC__C': 0.01, 'SVC__gamma': 'scale', 'SVC__...           0.959854
# 17  {'SVC__C': 0.01, 'SVC__gamma': 'scale', 'SVC__...           0.978102
# 18  {'SVC__C': 0.01, 'SVC__gamma': 'auto', 'SVC__k...           0.959854
# 19  {'SVC__C': 0.01, 'SVC__gamma': 'auto', 'SVC__k...           0.978102
# 20  {'SVC__C': 0.01, 'SVC__gamma': 0.2, 'SVC__kern...           1.000000
# 21  {'SVC__C': 0.01, 'SVC__gamma': 0.2, 'SVC__kern...           0.978102
# 22  {'SVC__C': 0.01, 'SVC__gamma': 0.3, 'SVC__kern...           1.000000
# 23  {'SVC__C': 0.01, 'SVC__gamma': 0.3, 'SVC__kern...           0.978102
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           1.000000           1.000000
# 1            0.963504           0.981752           0.968978
# 2            1.000000           1.000000           1.000000
# 3            0.963504           0.981752           0.968978
# 4            1.000000           1.000000           1.000000
# 5            0.963504           0.981752           0.968978
# 6            1.000000           1.000000           1.000000
# 7            0.963504           0.981752           0.968978
# 8            0.954380           0.967153           0.950730
# 9            0.976277           0.990876           0.983577
# 10           0.954380           0.967153           0.950730
# 11           0.976277           0.990876           0.983577
# 12           0.085766           0.087591           0.197080
# 13           0.976277           0.990876           0.983577
# 14           0.067518           0.069343           0.140511
# 15           0.976277           0.990876           0.983577
# 16           0.948905           0.943431           0.939781
# 17           0.970803           0.987226           0.978102
# 18           0.948905           0.943431           0.939781
# 19           0.970803           0.987226           0.978102
# 20           1.000000           1.000000           1.000000
# 21           0.970803           0.987226           0.978102
# 22           1.000000           1.000000           1.000000
# 23           0.970803           0.987226           0.978102
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 0            0.000000           0.000000           0.000000
# 1            0.972578           0.978062           0.972578
# 2            0.000000           0.000000           0.000000
# 3            0.972578           0.978062           0.972578
# 4            0.000000           0.000000           0.000000
# 5            0.972578           0.978062           0.972578
# 6            0.000000           0.000000           0.000000
# 7            0.972578           0.978062           0.972578
# 8            0.963437           0.961609           0.950640
# 9            0.981718           0.985375           0.978062
# 10           0.963437           0.961609           0.950640
# 11           0.981718           0.985375           0.978062
# 12           0.118830           0.106033           0.069470
# 13           0.981718           0.985375           0.978062
# 14           0.087751           0.082267           0.053016
# 15           0.981718           0.985375           0.978062
# 16           0.952468           0.967093           0.930530
# 17           0.974406           0.979890           0.974406
# 18           0.952468           0.965265           0.930530
# 19           0.974406           0.979890           0.974406
# 20           1.000000           1.000000           1.000000
# 21           0.974406           0.979890           0.974406
# 22           1.000000           1.000000           1.000000
# 23           0.974406           0.979890           0.974406
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0            0.000000           0.000000           1.000000         0.500000
# 1            0.968921           0.967093           0.972578         0.972232
# 2            0.000000           0.000000           1.000000         0.500000
# 3            0.968921           0.967093           0.972578         0.972232
# 4            0.000000           0.000000           1.000000         0.500000
# 5            0.968921           0.967093           0.972578         0.972232
# 6            0.000000           0.000000           1.000000         0.500000
# 7            0.968921           0.967093           0.972578         0.972232
# 8            0.957952           0.967093           0.959781         0.959628
# 9            0.978062           0.983547           0.979890         0.981914
# 10           0.957952           0.967093           0.959781         0.959628
# 11           0.978062           0.983547           0.979890         0.981914
# 12           0.133455           0.111517           0.096892         0.112525
# 13           0.978062           0.983547           0.979890         0.981914
# 14           0.095064           0.084095           0.078611         0.084029
# 15           0.978062           0.983547           0.979890         0.981914
# 16           0.948812           0.952468           0.941499         0.948484
# 17           0.970750           0.970750           0.976234         0.976067
# 18           0.948812           0.952468           0.941499         0.948301
# 19           0.970750           0.970750           0.976234         0.976067
# 20           1.000000           1.000000           0.000000         0.900000
# 21           0.970750           0.970750           0.976234         0.976067
# 22           1.000000           1.000000           0.000000         0.900000
# 23           0.970750           0.970750           0.976234         0.976067
#
#     std_test_score  rank_test_score
# 0         0.500000               19
# 1         0.005152                9
# 2         0.500000               19
# 3         0.005152                9
# 4         0.500000               19
# 5         0.005152                9
# 6         0.500000               19
# 7         0.005152                9
# 8         0.005798               13
# 9         0.004041                1
# 10        0.005798               13
# 11        0.004041                1
# 12        0.033382               23
# 13        0.004041                1
# 14        0.021936               24
# 15        0.004041                1
# 16        0.009900               15
# 17        0.004871                5
# 18        0.009565               16
# 19        0.004871                5
# 20        0.300000               17
# 21        0.004871                5
# 22        0.300000               17
# 23        0.004871                5

# %%
eval_metric(svm_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set:
# [[2117   38]
#  [  24 1801]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      2155
#            1       0.98      0.99      0.98      1825
#
#     accuracy                           0.98      3980
#    macro avg       0.98      0.98      0.98      3980
# weighted avg       0.98      0.98      0.98      3980
#
#
# Train_Set:
# [[6365  100]
#  [  95 5379]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      6465
#            1       0.98      0.98      0.98      5474
#
#     accuracy                           0.98     11939
#    macro avg       0.98      0.98      0.98     11939
# weighted avg       0.98      0.98      0.98     11939

# %%
pipe3 = Pipeline(steps = [('scaler', StandardScaler()),
                          ('SVC', SVC(C = 0.05, gamma = 'scale', kernel = 'linear', class_weight = 'balanced',
                                      probability = True, random_state = 42))])

# %%
scores_grid = cross_validate(pipe3, X_train, y_train, scoring = ['precision', 'recall', 'f1'], cv = 10)

# %%
scores_grid_df = pd.DataFrame(scores_grid, index = range(1, 11))
scores_grid_df
# Out:
#      fit_time  score_time  test_precision  test_recall   test_f1
# 1   10.509845    0.046298        0.976407     0.981752  0.979072
# 2   10.116909    0.035883        0.987085     0.976277  0.981651
# 3   11.389016    0.048367        0.983696     0.990876  0.987273
# 4   10.213261    0.037666        0.981785     0.983577  0.982680
# 5   10.689426    0.042743        0.971067     0.981718  0.976364
# 6   11.356061    0.043047        0.987179     0.985375  0.986276
# 7   10.581424    0.039154        0.969203     0.978062  0.973612
# 8   11.589080    0.040922        0.987085     0.978062  0.982553
# 9   11.789468    0.041926        0.971119     0.983547  0.977293
# 10  11.566966    0.044797        0.979890     0.979890  0.979890

# %%
scores_grid_df.iloc[:, 2:].mean()
# Out:
# test_precision    0.979452
# test_recall       0.981914
# test_f1           0.980666
# dtype: float64

# %%
svm_grid.decision_function(X_test)
# Out:
# array([-6.84622144,  2.78820043,  1.54324522, ..., -3.41076645,
#        -3.16522009, -4.19779644])

# %%
svm_grid.predict(X_test)
# Out:
# array([0, 1, 1, ..., 0, 0, 0])
